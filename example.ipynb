# %% [markdown]
# <a href="https://colab.research.google.com/github/gshatko/urban_analytics/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/ValeriyaTikhevich/solver_FLP.git@main
# Out:
# Collecting git+https://github.com/ValeriyaTikhevich/solver_FLP.git@main
#   Cloning https://github.com/ValeriyaTikhevich/solver_FLP.git (to revision main) to /tmp/pip-req-build-sons_iki
#   Running command git clone --filter=blob:none --quiet https://github.com/ValeriyaTikhevich/solver_FLP.git /tmp/pip-req-build-sons_iki
#   Resolved https://github.com/ValeriyaTikhevich/solver_FLP.git to commit 16fc023ce6c9b33bd9931ccaa63e1546630c025a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from solver_FLP==0.0.1) (2.0.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from solver_FLP==0.0.1) (2.2.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from solver_FLP==0.0.1) (1.0.1)
# Collecting pulp (from solver_FLP==0.0.1)
#   Downloading PuLP-3.0.2-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from solver_FLP==0.0.1) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from solver_FLP==0.0.1) (4.67.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from solver_FLP==0.0.1) (18.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->solver_FLP==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->solver_FLP==0.0.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->solver_FLP==0.0.1) (2025.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->solver_FLP==0.0.1) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas->solver_FLP==0.0.1) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->solver_FLP==0.0.1) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->solver_FLP==0.0.1) (2.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->solver_FLP==0.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->solver_FLP==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->solver_FLP==0.0.1) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->solver_FLP==0.0.1) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->solver_FLP==0.0.1) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->solver_FLP==0.0.1) (3.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas->solver_FLP==0.0.1) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->solver_FLP==0.0.1) (1.17.0)
# Downloading PuLP-3.0.2-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 28.6 MB/s eta 0:00:00
# Building wheels for collected packages: solver_FLP
#   Building wheel for solver_FLP (pyproject.toml) ... done
#   Created wheel for solver_FLP: filename=solver_flp-0.0.1-py3-none-any.whl size=9987 sha256=adb5285002e8942131d96809826054121d7f16c158fab76aa403ab52af1c2360
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xmiyjdlo/wheels/8f/9c/dd/929ec63c056f1997764422a596ab1993ca8f8d1d0f739fcc4c
# Successfully built solver_FLP
# Installing collected packages: pulp, solver_FLP
# Successfully installed pulp-3.0.2 solver_FLP-0.0.1

# %%
from method import genetic_algorithm_main, choose_edges, fitness_plot

# %%
from method import genetic_algorithm_main, choose_edges, fitness_plot, block_coverage, services_plot, connect_blocks_plot
import os
import pandas as pd
import geopandas as gpd
import numpy as np

local_crs = 32636
example_data_path = "./data/"

import warnings
warnings.filterwarnings("ignore")

# %%
accessibility_matrix = pd.read_pickle(os.path.join("/data/data_getter_matrix.pickle"))
df_with_demand = gpd.read_file(os.path.join("/data/df_with_demand.geojson")).to_crs(local_crs)
df_with_demand.head()
# Out:
#    id  capacity  demand  demand_left  demand_within  demand_without  \
# 0   0       0.0     3.0          3.0            0.0             3.0
# 1   1       0.0     3.0          3.0            0.0             3.0
# 2   2    4441.0    37.0         37.0           37.0             0.0
# 3   3       0.0    10.0         10.0           10.0             0.0
# 4   4       0.0    14.0         14.0            0.0            14.0
#
#    capacity_left  provision                                           geometry
# 0            0.0        0.0  POLYGON ((339076.063 6636586.371, 339075.615 6...
# 1            0.0        0.0  POLYGON ((338883.944 6636688.475, 338884.04 66...
# 2           10.0        1.0  POLYGON ((339907.94 6636293.887, 339907.941 66...
# 3            0.0        1.0  POLYGON ((340896.896 6635327.538, 340889.1 663...
# 4            0.0        0.0  POLYGON ((340830.836 6636349.591, 340830.388 6...

# %%
SERVICE_RADIUS = 15

# Genetic algorithm parameters
population_size = 50
num_generations = 20
num_parents = 10
num_offspring = population_size - num_parents
mutation_rate = 0.7

# %%
uncovered_demand = df_with_demand[df_with_demand['provision'] < 1]
accessibility_matrix_uncovered_demand = accessibility_matrix.loc[uncovered_demand.index, uncovered_demand.index]
id_matrix = accessibility_matrix_uncovered_demand.index.tolist()

uncovered_demand.reset_index(drop=True, inplace=True)
accessibility_matrix_uncovered_demand.reset_index(drop=True, inplace=True)
accessibility_matrix_uncovered_demand.columns=accessibility_matrix_uncovered_demand.index

# %%
edges_uncovered_demand = choose_edges(sim_matrix = accessibility_matrix_uncovered_demand, service_radius = SERVICE_RADIUS)
len(edges_uncovered_demand)
# Out:
# 100%|██████████| 22/22 [00:00<00:00, 434.68it/s]
# 23

# %%
best_candidate, fitness_history = genetic_algorithm_main(matrix = accessibility_matrix_uncovered_demand,
                                   edges = edges_uncovered_demand, population_size = population_size,
                                   num_generations = num_generations, df = uncovered_demand,
                                   service_radius = SERVICE_RADIUS, mutation_rate = mutation_rate,
                                   num_parents = num_parents, num_offspring = num_offspring, number_res = 'all')
# Out:
# 100%|██████████| 20/20 [01:17<00:00,  3.88s/it]

# %%
fitness_plot(fitness_history)

# %%
capacities, res_id = block_coverage(best_candidate, SERVICE_RADIUS, uncovered_demand, id_matrix)

print([num for num in capacities if num > 0])
res_id
# Out:
# [50.0, 69.0, 450.0, 74.0, 50.0, 50.0, 50.0, 50.0, 50.0]
# {0: [0, 1],
#  10: [4, 8, 9, 10],
#  15: [5, 6, 7, 14, 15, 31],
#  27: [19, 27, 32],
#  39: [39],
#  47: [47],
#  53: [53],
#  56: [55, 56, 57],
#  65: [65]}

# %%
selected_potential_services = gpd.GeoDataFrame(df_with_demand.loc[:, 'geometry']).loc[list(res_id.keys()), :]
selected_potential_services['capacity'] = [capacity for capacity in capacities if capacity > 0]

arr_index = np.intersect1d(selected_potential_services.index, df_with_demand[df_with_demand['capacity']>0].index)

for i in arr_index:
    selected_potential_services.loc[i, 'capacity'] += df_with_demand.loc[i, 'capacity']

# %%
df_opt = df_with_demand.sjoin(selected_potential_services.to_crs(local_crs), how='left', lsuffix='osn').fillna(0)
df_opt['capacity'] = df_opt['capacity_osn'] + df_opt['capacity_right']
df_opt.drop(columns = ['capacity_osn', 'index_right', 'capacity_right'], inplace=True)

# %%
policlinics = gpd.read_file(os.path.join("/data/policlinics.geojson")).to_crs(local_crs)
policlinics['our_service'] = policlinics[policlinics['geometry'].notnull()]['geometry'].apply(lambda point: '+' if any(point.within(poly) for poly in df_opt.drop(arr_index)['geometry']) else '-')

# %%
services_plot(df_with_demand, df_opt, res_id,
              policlinics, size_factor=100, alpha=0.05,
              size_factor_2=100, alpha_2=0.05, x=20, y=50, x_2=10, y_2=50)

# %%
connect_blocks_plot(id_matrix, accessibility_matrix_uncovered_demand, df_opt, best_candidate)
